# %%
print("aman")
# Out:
# aman

# %%
print("I love bangladesh")
# Out:
# I love bangladesh

# %%
PIPELINE_NAME: str = "usvisa"
ARTIFACT_DIR: str = "artifact"

# %%
print(PIPELINE_NAME)
# Out:
# usvisa

# %%
print(type(PIPELINE_NAME))
# Out:
# <class 'str'>

# %%
import os

base_artifact = os.path.join(ARTIFACT_DIR, PIPELINE_NAME)
print(base_artifact)
os.makedirs(base_artifact, exist_ok=True)
# এরপর subdirs তৈরি
for sub in ["data_ingestion", "data_validation", "data_transformation", "model_trainer"]:
    print(sub)
    os.makedirs(os.path.join(base_artifact, sub),exist_ok=True)
    dir= os.path.join(base_artifact,sub)
    print(dir)
# Out:
# artifact\usvisa
# data_ingestion
# artifact\usvisa\data_ingestion
# data_validation
# artifact\usvisa\data_validation
# data_transformation
# artifact\usvisa\data_transformation
# model_trainer
# artifact\usvisa\model_trainer

# %%
os.path.join("config", "schema.yaml")
# Out:
# 'config\\schema.yaml'

# %%
import sys

print("Python version:", sys.version)
# Out:
# Python version: 3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]

# %%
import sys

print(sys.path)  # সব মডিউল সার্চ পাথ দেখাবে
# Out:
# ['d:\\inceptionBD\\Assignments\\JARVIS-voice-assistant-system\\jarvis\\python311.zip', 'd:\\inceptionBD\\Assignments\\JARVIS-voice-assistant-system\\jarvis\\DLLs', 'd:\\inceptionBD\\Assignments\\JARVIS-voice-assistant-system\\jarvis\\Lib', 'd:\\inceptionBD\\Assignments\\JARVIS-voice-assistant-system\\jarvis', '', 'd:\\inceptionBD\\Assignments\\JARVIS-voice-assistant-system\\jarvis\\Lib\\site-packages', 'D:\\inceptionBD\\projects\\youtube-renderer-pypi-package\\src', 'd:\\inceptionBD\\Assignments\\JARVIS-voice-assistant-system\\jarvis\\Lib\\site-packages\\win32', 'd:\\inceptionBD\\Assignments\\JARVIS-voice-assistant-system\\jarvis\\Lib\\site-packages\\win32\\lib', 'd:\\inceptionBD\\Assignments\\JARVIS-voice-assistant-system\\jarvis\\Lib\\site-packages\\Pythonwin']

# %%
import sys
print(sys.platform)
# Out:
# win32
